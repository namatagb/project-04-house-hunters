# %%
import pandas as pd

# %%
path1 = "Raw Data\SUB-EST2020_ALL.csv"
countrydf = pd.read_csv(path1, encoding='utf-8')
countrydf
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15300/3168602223.py in <module>
#       1 path1 = "Raw Data\SUB-EST2020_ALL.csv"
# ----> 2 countrydf = pd.read_csv(path1, encoding='utf-8')
#       3 countrydf
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 118162: invalid continuation byte

# %%
countrydf1 = pd.DataFrame(countrydf[["NAME", "STNAME", "POPESTIMATE2020"]])
countrydf1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15300/1141713274.py in <module>
# ----> 1 countrydf1 = pd.DataFrame(countrydf[["NAME", "STNAME", "POPESTIMATE2020"]])
#       2 countrydf1
#
# NameError: name 'countrydf' is not defined

# %%
countrydf1 = countrydf1[countrydf1['NAME'].str.contains("city")]
countrydf1
# Out:
#                       NAME   STNAME  POPESTIMATE2020
# 1           Abbeville city  Alabama             2553
# 2          Adamsville city  Alabama             4211
# 5           Alabaster city  Alabama            33701
# 6         Albertville city  Alabama            21777
# 7      Alexander City city  Alabama            14142
# ...                    ...      ...              ...
# 81393     Green River city  Wyoming            11788
# 81394    Rock Springs city  Wyoming            22943
# 81403        Evanston city  Wyoming            11570
# 81409         Worland city  Wyoming             4994
# 81412       Newcastle city  Wyoming             3314
#
# [27983 rows x 3 columns]

# %%
countrydf1 = countrydf1.replace({'Alabama': 'AL', 
                                 'Alaska': 'AK',
                                 'Arizona': 'AZ',
                                 'Arkansas': 'AR',
                                 'California': 'CA',
                                 'Colorado': 'CO',
                                 'Connecticut': 'CT',
                                 'Delaware': 'DE',
                                 'District of Columbia': 'DC',
                                 'Florida': 'FL',
                                 'Georgia': 'GA',
                                 'Hawaii': 'HI',
                                 'Idaho': 'ID',
                                 'Illinois': 'IL',
                                 'Indiana': 'IN',
                                 'Iowa': 'IA',
                                 'Kansas': 'KS',
                                 'Kentucky': 'KY',
                                 'Louisiana': 'LA',
                                 'Maine': 'ME',
                                 'Maryland': 'MD',
                                 'Massachusetts': 'MA',
                                 'Michigan': 'MI',
                                 'Minnesota': 'MN',
                                 'Mississippi': 'MS',
                                 'Missouri': 'MO',
                                 'Montana': 'MT',
                                 'Nebraska': 'NE',
                                 'Nevada': 'NV',
                                 'New Hampshire': 'NH',
                                 'New Jersey': 'NJ',
                                 'New Mexico': 'NM',
                                 'New York': 'NY',
                                 'North Carolina': 'NC',
                                 'North Dakota': 'ND',
                                 'Ohio': 'OH',
                                 'Oklahoma': 'OK',
                                 'Oregon': 'OR',
                                 'Pennsylvania': 'PA',
                                 'Rhode Island': 'RI',
                                 'South Carolina': 'SC',
                                 'South Dakota': 'SD',
                                 'Tennessee': 'TN',
                                 'Texas': 'TX',
                                 'Utah': 'UT',
                                 'Vermont': 'VT',
                                 'Virginia': 'VA',
                                 'Washington': 'WA',
                                 'West Virginia': 'WV',
                                 'Wisconsin': 'WI',
                                 'Wyoming': 'WY'
                                }, regex=True)
countrydf1.head()
# Out:
#                   NAME STNAME  POPESTIMATE2020
# 1       Abbeville city     AL             2553
# 2      Adamsville city     AL             4211
# 5       Alabaster city     AL            33701
# 6     Albertville city     AL            21777
# 7  Alexander City city     AL            14142

# %%
countrydf1["CityName"] = countrydf1['NAME'].str.replace(' city', '')
countrydf1
# Out:
#                       NAME STNAME  POPESTIMATE2020        CityName  \
# 1           Abbeville city     AL             2553       Abbeville
# 2          Adamsville city     AL             4211      Adamsville
# 5           Alabaster city     AL            33701       Alabaster
# 6         Albertville city     AL            21777     Albertville
# 7      Alexander City city     AL            14142  Alexander City
# ...                    ...    ...              ...             ...
# 81393     Green River city     WY            11788     Green River
# 81394    Rock Springs city     WY            22943    Rock Springs
# 81403        Evanston city     WY            11570        Evanston
# 81409         Worland city     WY             4994         Worland
# 81412       Newcastle city     WY             3314       Newcastle
#
#                 RegionName
# 1           Abbeville , AL
# 2          Adamsville , AL
# 5           Alabaster , AL
# 6         Albertville , AL
# 7      Alexander City , AL
# ...                    ...
# 81393     Green River , WY
# 81394    Rock Springs , WY
# 81403        Evanston , WY
# 81409         Worland , WY
# 81412       Newcastle , WY
#
# [27983 rows x 5 columns]

# %%
countrydf1['RegionName'] = countrydf1['CityName'].str.cat(countrydf1['STNAME'], sep=', ')
countrydf1
# Out:
#                       NAME STNAME  POPESTIMATE2020        CityName  \
# 1           Abbeville city     AL             2553       Abbeville
# 2          Adamsville city     AL             4211      Adamsville
# 5           Alabaster city     AL            33701       Alabaster
# 6         Albertville city     AL            21777     Albertville
# 7      Alexander City city     AL            14142  Alexander City
# ...                    ...    ...              ...             ...
# 81393     Green River city     WY            11788     Green River
# 81394    Rock Springs city     WY            22943    Rock Springs
# 81403        Evanston city     WY            11570        Evanston
# 81409         Worland city     WY             4994         Worland
# 81412       Newcastle city     WY             3314       Newcastle
#
#                RegionName
# 1           Abbeville, AL
# 2          Adamsville, AL
# 5           Alabaster, AL
# 6         Albertville, AL
# 7      Alexander City, AL
# ...                   ...
# 81393     Green River, WY
# 81394    Rock Springs, WY
# 81403        Evanston, WY
# 81409         Worland, WY
# 81412       Newcastle, WY
#
# [27983 rows x 5 columns]

# %%
cleanpopulationdf = pd.DataFrame(countrydf1[["RegionName", "POPESTIMATE2020"]])
cleanpopulationdf
# Out:
#                RegionName  POPESTIMATE2020
# 1           Abbeville, AL             2553
# 2          Adamsville, AL             4211
# 5           Alabaster, AL            33701
# 6         Albertville, AL            21777
# 7      Alexander City, AL            14142
# ...                   ...              ...
# 81393     Green River, WY            11788
# 81394    Rock Springs, WY            22943
# 81403        Evanston, WY            11570
# 81409         Worland, WY             4994
# 81412       Newcastle, WY             3314
#
# [27983 rows x 2 columns]

# %%
cleanpopulationdf.to_csv('cleanpopulationdf.csv', index=False)
