# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None

# %%
path1 = "MedianDaysToClose.csv"
path2 = "MedianDaysToPending.csv"
path3 = "ZillowHomeValues.csv"
path4 = "cleanpopulationdf.csv"

closedf = pd.read_csv(path1)
pendingdf = pd.read_csv(path2)
homevaldf = pd.read_csv(path3)
cleanpopdf = pd.read_csv(path4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29424/3351906530.py in <module>
#       7 pendingdf = pd.read_csv(path2)
#       8 homevaldf = pd.read_csv(path3)
# ----> 9 cleanpopdf = pd.read_csv(path4)
#      10
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cleanpopulationdf.csv'

# %%
#combining the days from list to pending, and the days from pending to close creates total days on market
daysonmarketdf = pd.concat([closedf, pendingdf]).groupby(['RegionID', 'RegionName','SizeRank']).sum().reset_index()
len(daysonmarketdf)

# %%
#making the list of anything that is a zero value

rows_to_drop = []
for i in daysonmarketdf.index.tolist(): #iterate over rows
    for j in daysonmarketdf.columns.tolist(): #iterate over columns
        value = daysonmarketdf.loc[i, j] #get cell value
        if (value == 0):
            rows_to_drop.append(i)
            break
len(rows_to_drop)

# %%
#dropping anything with a zero value from the df

prefinaldaysdf = daysonmarketdf.drop(index = rows_to_drop)

# %%
prefinaldaysdf

# %%
#dropping all the columns before January 2020

finaldaysdf = prefinaldaysdf.drop(columns=['1/31/2018', '2/28/2018', '3/31/2018', '4/30/2018', '5/31/2018', '6/30/2018',
                             '7/31/2018', '8/31/2018', '9/30/2018', '10/31/2018', '11/30/2018', '12/31/2018',
                             '1/31/2019', '2/28/2019', '3/31/2019', '4/30/2019', '5/31/2019', '6/30/2019',
                             '7/31/2019', '8/31/2019', '9/30/2019', '10/31/2019', '11/30/2019', '12/31/2019'])

# %%
finaldaysdf

# %%
#dropping all the columns before Jan 2020
droppedvaldf = homevaldf.drop(columns=['1/31/2018', '2/28/2018', '3/31/2018', '4/30/2018', '5/31/2018', '6/30/2018',
                             '7/31/2018', '8/31/2018', '9/30/2018', '10/31/2018', '11/30/2018', '12/31/2018',
                             '1/31/2019', '2/28/2019', '3/31/2019', '4/30/2019', '5/31/2019', '6/30/2019',
                             '7/31/2019', '8/31/2019', '9/30/2019', '10/31/2019', '11/30/2019', '12/31/2019'])

# %%
#renaming column to match the other DF
prefinalvaldf = droppedvaldf.rename(columns = {'0':'RegionID'})
len(prefinalvaldf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29424/3149139008.py in <module>
#       1 #renaming column to match the other DF
# ----> 2 prefinalvaldf = droppedvaldf.rename(columns = {'0':'RegionID'})
#       3 len(prefinalvaldf)
#
# NameError: name 'droppedvaldf' is not defined

# %%
#creating a list of anything with zero to drop them

rows_to_drop2 = []
for i in prefinalvaldf.index.tolist(): #iterate over rows
    for j in prefinalvaldf.columns.tolist(): #iterate over columns
        value = prefinalvaldf.loc[i, j] #get cell value
        if (value == 0):
            rows_to_drop2.append(i)
            break
len(rows_to_drop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29424/2368173598.py in <module>
#       2
#       3 rows_to_drop2 = []
# ----> 4 for i in prefinalvaldf.index.tolist(): #iterate over rows
#       5     for j in prefinalvaldf.columns.tolist(): #iterate over columns
#       6         value = prefinalvaldf.loc[i, j] #get cell value
#
# NameError: name 'prefinalvaldf' is not defined

# %%
#dropping
prefinalvaldf.drop(index = rows_to_drop2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29424/4136006073.py in <module>
#       1 #dropping
# ----> 2 prefinalvaldf.drop(index = rows_to_drop2)
#
# NameError: name 'prefinalvaldf' is not defined

# %%
#this dataframe had a lot of emtpy columns, dropping using NA
finalvaldf = prefinalvaldf.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29424/2389919673.py in <module>
#       1 #this dataframe had a lot of emtpy columns, dropping using NA
# ----> 2 finalvaldf = prefinalvaldf.dropna()
#
# NameError: name 'prefinalvaldf' is not defined

# %%
#averaging the home value

finalvaldf
onlydatesdf = finalvaldf.drop(['RegionID', 'SizeRank'], axis=1)
onlydatesdf

finalvaldf['2020-NowAvg'] = onlydatesdf.mean(numeric_only=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29424/2691959193.py in <module>
#       1 #averaging the home value
#       2
# ----> 3 finalvaldf
#       4 onlydatesdf = finalvaldf.drop(['RegionID', 'SizeRank'], axis=1)
#       5 onlydatesdf
#
# NameError: name 'finalvaldf' is not defined

# %%
finalvaldf
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# 5      394974         5                    Philadelphia, PA        Msa
# ..        ...       ...                                 ...        ...
# 901    394330       926                         Andrews, TX        Msa
# 902    753929       927                          Zapata, TX        Msa
# 903    395186       928                      Vermillion, SD        Msa
# 906    394968       931                           Pecos, TX        Msa
# 908    394743       933                       Ketchikan, AK        Msa
#
#     StateName  1/31/2020  2/29/2020  3/31/2020  4/30/2020  5/31/2020  ...  \
# 1          NY   480737.0   482299.0   483893.0   485602.0   486639.0  ...
# 2          CA   709182.0   715685.0   723187.0   728674.0   726786.0  ...
# 3          IL   247212.0   247838.0   248386.0   248512.0   248354.0  ...
# 4          TX   261149.0   262104.0   263376.0   264013.0   264453.0  ...
# 5          PA   255500.0   256530.0   257043.0   258093.0   258936.0  ...
# ..        ...        ...        ...        ...        ...        ...  ...
# 901        TX   175727.0   176067.0   176358.0   176087.0   176374.0  ...
# 902        TX    93683.0    93695.0    93828.0    94633.0    95574.0  ...
# 903        SD   178789.0   179944.0   181119.0   182251.0   182188.0  ...
# 906        TX   126953.0   127343.0   128581.0   128329.0   128811.0  ...
# 908        AK   339002.0   338917.0   338531.0   337912.0   337765.0  ...
#
#      8/31/2021  9/30/2021  10/31/2021  11/30/2021  12/31/2021  1/31/2022  \
# 1     567784.0   574037.0    578902.0    582718.0    586214.0   590445.0
# 2     882698.0   892611.0    897888.0    905615.0    915573.0   927205.0
# 3     287900.0   291158.0    293988.0    296830.0    299700.0   302490.0
# 4     325128.0   332449.0    338641.0    344247.0    350282.0   357878.0
# 5     309959.0   312926.0    315460.0    318024.0    320384.0   323028.0
# ..         ...        ...         ...         ...         ...        ...
# 901   200431.0   202416.0    203216.0    203581.0    206900.0   209821.0
# 902   107504.0   108253.0    108801.0    109264.0    111553.0   114169.0
# 903   208273.0   209840.0    211020.0    211845.0    214896.0   218167.0
# 906   154675.0   159353.0    163987.0    165012.0    167734.0   170405.0
# 908   364220.0   366550.0    368505.0    369945.0    375671.0   381618.0
#
#      2/28/2022  3/31/2022  4/30/2022    2020-NowAvg
# 1     595360.0   602064.0     609442  534645.214286
# 2     940500.0   959260.0     979825  815820.821429
# 3     305217.0   308707.0     312363  272492.678571
# 4     366559.0   374813.0     384474  302522.357143
# 5     325668.0   329030.0     332832  289535.250000
# ..         ...        ...        ...            ...
# 901   213457.0   214108.0     216213  191378.428571
# 902   116899.0   117523.0     117795  103180.892857
# 903   222689.0   224693.0     226815  198096.071429
# 906   172820.0   174576.0     177218  145628.678571
# 908   386522.0   386902.0     387494  355734.607143
#
# [630 rows x 34 columns]

# %%
#averaging the days 

onlydatesdaysdf = finaldaysdf.drop(['RegionID', 'SizeRank'], axis=1)

finaldaysdf['2020-NowAvgDays'] = onlydatesdaysdf.mean(numeric_only=True, axis=1)

# %%
finaldaysdf
# Out:
#      RegionID                     RegionName  SizeRank  1/31/2020  2/29/2020  \
# 1      394298                   Aberdeen, WA       468       13.0       16.0
# 2      394299                    Abilene, TX       245       60.0       39.0
# 3      394300                        Ada, OK       730       68.0       19.0
# 4      394302                     Adrian, MI       379       97.0       73.0
# 5      394304                      Akron, OH        74       79.0       51.0
# ..        ...                            ...       ...        ...        ...
# 763    753917  Santa Maria-Santa Barbara, CA       120       77.0       40.0
# 764    753920                     Sonora, CA       550       93.0       75.0
# 765    753921          Steamboat Springs, CO       872       69.0       95.0
# 766    753922                Summit Park, UT       751       75.0       74.0
# 768    753924             Urban Honolulu, HI        54       54.0       37.0
#
#      3/31/2020  4/30/2020  5/31/2020  6/30/2020  7/31/2020  ...  8/31/2021  \
# 1         10.0       18.0        8.0       10.0       11.0  ...       42.0
# 2         35.0       29.0       32.0       26.0       26.0  ...       18.0
# 3         30.0       41.0       69.0       57.0       59.0  ...       62.0
# 4         63.0       85.0       60.0       62.0       64.0  ...       55.0
# 5         48.0       25.0       50.0       46.0       46.0  ...       43.0
# ..         ...        ...        ...        ...        ...  ...        ...
# 763       41.0       48.0       59.0       56.0       50.0  ...       39.0
# 764       46.0       49.0       43.0       39.0       32.0  ...       11.0
# 765       24.0       64.0       33.0       31.0       38.0  ...        8.0
# 766      108.0       24.0       68.0       50.0       58.0  ...       50.0
# 768       37.0       45.0       42.0       37.0       33.0  ...       12.0
#
#      9/30/2021  10/31/2021  11/30/2021  12/31/2021  1/31/2022  2/28/2022  \
# 1         47.0        51.0        53.0        57.0       59.0       38.0
# 2         23.0        24.0        20.0        25.0       16.0       51.0
# 3         53.0        54.0        69.0        66.0       64.0       70.0
# 4         48.0        58.0        54.0        67.0       69.0       49.0
# 5         47.0        45.0        46.0        48.0       51.0       40.0
# ..         ...         ...         ...         ...        ...        ...
# 763       39.0        39.0        38.0        42.0       42.0       37.0
# 764       15.0        16.0        33.0        44.0       62.0       15.0
# 765       10.0        13.0        10.0        19.0       16.0       10.0
# 766       52.0        46.0        40.0        50.0       39.0       38.0
# 768       11.0        13.0        13.0        14.0       16.0       11.0
#
#      3/31/2022  4/30/2022  2020-NowAvgDays
# 1          8.0       10.0        31.857143
# 2         33.0       37.0        28.321429
# 3         51.0       49.0        58.285714
# 4         37.0       43.0        60.035714
# 5         39.0       37.0        46.392857
# ..         ...        ...              ...
# 763       36.0       37.0        43.928571
# 764       12.0       10.0        30.178571
# 765        7.0        6.0        21.714286
# 766       37.0       37.0        54.285714
# 768       12.0       11.0        23.964286
#
# [468 rows x 32 columns]

# %%
mergedaysandvaluedf = pd.merge(finalvaldf,finaldaysdf, how = "inner", on = ["RegionID","RegionName","SizeRank"])
mergedaysandvaluedf.to_csv('mergedaysandvalue.csv') 

mergedaysandvaluedf
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      394913         1                        New York, NY        Msa
# 1      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 2      394463         3                         Chicago, IL        Msa
# 3      394514         4               Dallas-Fort Worth, TX        Msa
# 4      394974         5                    Philadelphia, PA        Msa
# ..        ...       ...                                 ...        ...
# 377    394300       730                             Ada, OK        Msa
# 378    394916       743                          Newton, IA        Msa
# 379    753922       751                     Summit Park, UT        Msa
# 380    394315       758                      Alexandria, MN        Msa
# 381    753871       837                    Breckenridge, CO        Msa
#
#     StateName  1/31/2020_x  2/29/2020_x  3/31/2020_x  4/30/2020_x  \
# 0          NY     480737.0     482299.0     483893.0     485602.0
# 1          CA     709182.0     715685.0     723187.0     728674.0
# 2          IL     247212.0     247838.0     248386.0     248512.0
# 3          TX     261149.0     262104.0     263376.0     264013.0
# 4          PA     255500.0     256530.0     257043.0     258093.0
# ..        ...          ...          ...          ...          ...
# 377        OK     105369.0     105517.0     105636.0     105648.0
# 378        IA     132024.0     131862.0     131643.0     131667.0
# 379        UT     923901.0     927703.0     933915.0     938919.0
# 380        MN     237179.0     237022.0     236797.0     236522.0
# 381        CO     954055.0     954823.0     954066.0     954548.0
#
#      5/31/2020_x  ...  8/31/2021_y  9/30/2021_y  10/31/2021_y  11/30/2021_y  \
# 0       486639.0  ...         94.0         96.0          96.0         101.0
# 1       726786.0  ...         43.0         43.0          43.0          43.0
# 2       248354.0  ...         55.0         57.0          59.0          61.0
# 3       264453.0  ...         38.0         40.0          39.0          39.0
# 4       258936.0  ...         54.0         54.0          54.0          53.0
# ..           ...  ...          ...          ...           ...           ...
# 377     104732.0  ...         62.0         53.0          54.0          69.0
# 378     131725.0  ...         54.0         51.0          53.0          56.0
# 379     941313.0  ...         50.0         52.0          46.0          40.0
# 380     237421.0  ...         10.0         14.0          32.0          17.0
# 381     958980.0  ...         51.0         50.0          42.0          49.0
#
#      12/31/2021_y  1/31/2022_y  2/28/2022_y  3/31/2022_y  4/30/2022_y  \
# 0            96.0        109.0         89.0         78.0         73.0
# 1            44.0         44.0         38.0         38.0         38.0
# 2            68.0         63.0         44.0         43.0         43.0
# 3            41.0         40.0         35.0         28.0         32.0
# 4            58.0         59.0         48.0         45.0         44.0
# ..            ...          ...          ...          ...          ...
# 377          66.0         64.0         70.0         51.0         49.0
# 378          61.0         72.0         53.0         48.0         49.0
# 379          50.0         39.0         38.0         37.0         37.0
# 380          32.0         21.0         12.0         43.0         45.0
# 381          46.0         50.0         41.0         43.0          5.0
#
#      2020-NowAvgDays
# 0          92.142857
# 1          45.107143
# 2          59.178571
# 3          42.392857
# 4          55.750000
# ..               ...
# 377        58.285714
# 378        59.928571
# 379        54.285714
# 380        27.285714
# 381        46.678571
#
# [382 rows x 63 columns]

# %%
cleanpopdf
# Out:
#                RegionName  POPESTIMATE2020
# 0           Abbeville, AL             2553
# 1          Adamsville, AL             4211
# 2           Alabaster, AL            33701
# 3         Albertville, AL            21777
# 4      Alexander City, AL            14142
# ...                   ...              ...
# 27978     Green River, WY            11788
# 27979    Rock Springs, WY            22943
# 27980        Evanston, WY            11570
# 27981         Worland, WY             4994
# 27982       Newcastle, WY             3314
#
# [27983 rows x 2 columns]

# %%
mergepopandzillow = pd.merge(mergedaysandvaluedf,cleanpopdf, how = "inner", on = ["RegionName"])
mergepopandzillowdf = mergepopandzillow.drop_duplicates(subset=["RegionName"], keep = 'first')
mergepopandzillowdf.to_csv('mergepopandzillowdf.csv') 

mergepopandzillowdf
# Out:
#      RegionID  SizeRank        RegionName RegionType StateName  1/31/2020_x  \
# 0      394463         3       Chicago, IL        Msa        IL     247212.0
# 3      394974         5  Philadelphia, PA        Msa        PA     255500.0
# 5      394692         6       Houston, TX        Msa        TX     224853.0
# 6      394347         9       Atlanta, GA        Msa        GA     247708.0
# 7      394404        10        Boston, MA        Msa        MA     512729.0
# ..        ...       ...               ...        ...       ...          ...
# 798    394500       658      Cornelia, GA        Msa        GA     165287.0
# 800    394548       665        Durant, OK        Msa        OK     123122.0
# 802    394300       730           Ada, OK        Msa        OK     105369.0
# 804    394916       743        Newton, IA        Msa        IA     132024.0
# 806    394315       758    Alexandria, MN        Msa        MN     237179.0
#
#      2/29/2020_x  3/31/2020_x  4/30/2020_x  5/31/2020_x  ...  9/30/2021_y  \
# 0       247838.0     248386.0     248512.0     248354.0  ...         57.0
# 3       256530.0     257043.0     258093.0     258936.0  ...         54.0
# 5       225077.0     225679.0     226724.0     227327.0  ...         47.0
# 6       249213.0     250298.0     251368.0     251951.0  ...         38.0
# 7       514859.0     517514.0     518977.0     520223.0  ...         52.0
# ..           ...          ...          ...          ...  ...          ...
# 798     166031.0     166980.0     167782.0     168384.0  ...         40.0
# 800     123333.0     123466.0     123551.0     123854.0  ...         60.0
# 802     105517.0     105636.0     105648.0     104732.0  ...         53.0
# 804     131862.0     131643.0     131667.0     131725.0  ...         51.0
# 806     237022.0     236797.0     236522.0     237421.0  ...         14.0
#
#      10/31/2021_y  11/30/2021_y  12/31/2021_y  1/31/2022_y  2/28/2022_y  \
# 0            59.0          61.0          68.0         63.0         44.0
# 3            54.0          53.0          58.0         59.0         48.0
# 5            44.0          45.0          46.0         47.0         39.0
# 6            37.0          38.0          40.0         41.0         36.0
# 7            51.0          52.0          57.0         55.0         50.0
# ..            ...           ...           ...          ...          ...
# 798          38.0          43.0          44.0         45.0         41.0
# 800          80.0          62.0          93.0         63.0         52.0
# 802          54.0          69.0          66.0         64.0         70.0
# 804          53.0          56.0          61.0         72.0         53.0
# 806          32.0          17.0          32.0         21.0         12.0
#
#      3/31/2022_y  4/30/2022_y  2020-NowAvgDays  POPESTIMATE2020
# 0           43.0         43.0        59.178571          2677643
# 3           45.0         44.0        55.750000          1578487
# 5           37.0         37.0        50.035714          2316120
# 6           34.0         33.0        42.821429           512550
# 7           46.0         47.0        54.285714           691531
# ..           ...          ...              ...              ...
# 798         40.0         36.0        48.750000             4799
# 800         58.0         49.0        39.000000            19157
# 802         51.0         49.0        58.285714            17239
# 804         48.0         49.0        59.928571            15127
# 806         43.0         45.0        27.285714            13885
#
# [336 rows x 64 columns]

# %%
print(mergepopandzillowdf.columns)
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        '1/31/2020_x', '2/29/2020_x', '3/31/2020_x', '4/30/2020_x',
#        '5/31/2020_x', '6/30/2020_x', '7/31/2020_x', '8/31/2020_x',
#        '9/30/2020_x', '10/31/2020_x', '11/30/2020_x', '12/31/2020_x',
#        '1/31/2021_x', '2/28/2021_x', '3/31/2021_x', '4/30/2021_x',
#        '5/31/2021_x', '6/30/2021_x', '7/31/2021_x', '8/31/2021_x',
#        '9/30/2021_x', '10/31/2021_x', '11/30/2021_x', '12/31/2021_x',
#        '1/31/2022_x', '2/28/2022_x', '3/31/2022_x', '4/30/2022_x',
#        '2020-NowAvg', '1/31/2020_y', '2/29/2020_y', '3/31/2020_y',
#        '4/30/2020_y', '5/31/2020_y', '6/30/2020_y', '7/31/2020_y',
#        '8/31/2020_y', '9/30/2020_y', '10/31/2020_y', '11/30/2020_y',
#        '12/31/2020_y', '1/31/2021_y', '2/28/2021_y', '3/31/2021_y',
#        '4/30/2021_y', '5/31/2021_y', '6/30/2021_y', '7/31/2021_y',
#        '8/31/2021_y', '9/30/2021_y', '10/31/2021_y', '11/30/2021_y',
#        '12/31/2021_y', '1/31/2022_y', '2/28/2022_y', '3/31/2022_y',
#        '4/30/2022_y', '2020-NowAvgDays', 'POPESTIMATE2020'],
#       dtype='object')

# %%
finaldf = mergepopandzillowdf[["2020-NowAvgDays","POPESTIMATE2020","RegionName","2020-NowAvg"]].copy()

# %%
newfinaldf = finaldf.rename(columns={"2020-NowAvgDays": "DaysOnMarket", "2020-NowAvg": "HomeValue"})

# %%
newfinaldf
# Out:
#      DaysOnMarket  POPESTIMATE2020        RegionName      HomeValue
# 0       59.178571          2677643       Chicago, IL  272492.678571
# 3       55.750000          1578487  Philadelphia, PA  289535.250000
# 5       50.035714          2316120       Houston, TX  252338.964286
# 6       42.821429           512550       Atlanta, GA  291759.678571
# 7       54.285714           691531        Boston, MA  581767.607143
# ..            ...              ...               ...            ...
# 798     48.750000             4799      Cornelia, GA  185672.500000
# 800     39.000000            19157        Durant, OK  133609.928571
# 802     58.285714            17239           Ada, OK  113388.142857
# 804     59.928571            15127        Newton, IA  140421.464286
# 806     27.285714            13885    Alexandria, MN  261901.214286
#
# [336 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
newfinaldf.to_csv('finaldf.csv')

# %%
y = newfinaldf["POPESTIMATE2020"]
X = newfinaldf.drop(["POPESTIMATE2020", "RegionName"], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.003968253968253968
# Testing Data Score: 0.0

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# Fitting our model with all our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.06598335673847966
